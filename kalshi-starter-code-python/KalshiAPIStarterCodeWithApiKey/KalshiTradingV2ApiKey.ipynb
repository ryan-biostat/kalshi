# %%
# Welcome to the Kalshi REST v2 Starter Code!

# pypi client: recommended for more advanced programmers
#import kalshi_python

# starter client: recommended for all levels of programming experience (what this client is implemented using)
from KalshiClientsBaseV2ApiKey import ExchangeClient
import time
import json
import uuid

# %%
from cryptography.hazmat.primitives import serialization
from cryptography.hazmat.backends import default_backend

def load_private_key_from_file(file_path):
    with open(file_path, "rb") as key_file:
        private_key = serialization.load_pem_private_key(
            key_file.read(),
            password=None,  # or provide a password if your key is encrypted
            backend=default_backend()
        )
    return private_key

# %%
# To start off, you need to have created an account at https://kalshi.com (Production)
# or an account on the Demo https://demo.kalshi.co/

## if wanting to test in prod change this to prod
env = "demo"

if env == "prod":
    key_id = "" # change these to be your personal credentials
    private_key = load_private_key_from_file('kalshi-prod-key.key')
    api_base = "https://api.elections.kalshi.com/trade-api/v2"
else:
    key_id = "" # change these to be your personal credentials
    private_key = load_private_key_from_file('kalshi-demo-key.key')
    api_base = "https://demo-api.kalshi.co/trade-api/v2"

exchange_client = ExchangeClient(
    exchange_api_base = api_base,
    key_id = key_id,
    private_key = private_key,
)

# first we will check on the exchange status to confirm you are properly connected...
print(exchange_client.get_exchange_status())
# Out:
# {'exchange_active': True, 'trading_active': True}

# %%
# You can discover markets through the get_markets endpoint...

# and use query parameters to filter your search!
market_params = {
    'limit':100,
    'cursor':None, # passing in the cursor from the previous get_markets call
    'event_ticker': None,
    'series_ticker':None,
    'max_close_ts':None, # pass in unix_ts
    'min_close_ts':None, # pass in unix_ts
    'status':None,
    'tickers':None
}
markets_response = exchange_client.get_markets(**market_params)
cursor = markets_response['cursor']

print('keys:', markets_response.keys())
print()
print('number of objects:', len(markets_response['markets'])) # 100 objects!
print()
print('first market in payload:', markets_response['markets'][0])
print()
print('cursor:', cursor)
# Out:
# keys: dict_keys(['markets', 'cursor'])
#
# number of objects: 100
#
# first market in payload: {'ticker': 'KXQUICKSETTLE-25MAY23H1600-3', 'event_ticker': 'KXQUICKSETTLE-25MAY23H1600', 'market_type': 'binary', 'title': 'Will 1+1 equal 3 on May 23 at 16:00?', 'subtitle': '', 'yes_sub_title': '3', 'no_sub_title': '3', 'open_time': '2025-05-23T19:50:00Z', 'close_time': '2025-05-23T20:00:00Z', 'expected_expiration_time': '2025-05-23T20:00:00Z', 'expiration_time': '2025-05-23T20:00:00Z', 'latest_expiration_time': '2025-05-23T20:00:00Z', 'settlement_timer_seconds': 60, 'status': 'initialized', 'response_price_units': 'usd_cent', 'notional_value': 100, 'tick_size': 1, 'yes_bid': 0, 'yes_ask': 0, 'no_bid': 100, 'no_ask': 100, 'last_price': 0, 'previous_yes_bid': 0, 'previous_yes_ask': 0, 'previous_price': 0, 'volume': 0, 'volume_24h': 0, 'liquidity': 0, 'open_interest': 0, 'result': '', 'can_close_early': True, 'expiration_value': '', 'category': '', 'risk_limit_cents': 0, 'rules_primary': 'If 1+1 equals 3 on May 23 at 16:00 the market resolves to Yes.', 'rules_secondary': ''}
#
# cursor: CgwI2pTCwQYQgPj9vQMSH0tYU1BPVElGWUFVU1RSQUxJQUQtMjVNQVkyNC1VTkQ

# %%
# What are cursors and how do they work?
    
# The Cursor represents a pointer to the next page of records in the pagination.
# So this optional parameter, when filled, should be filled with the cursor string returned in a previous request to this end-point.
# Filling this would basically tell the api to get the next page containing the number of records passed on the limit parameter.
# On the other side not filling it tells the api you want to get the first page for another query.
# The cursor does not store any filters, so if any filter parameters like tickers, max_ts or min_ts were passed in the original query they must be passed again.

# Let's try it in action! Suppose we wanted to get the next 100 market objects...

market_params = {'limit':100,
                    'cursor':cursor, # passing in the cursor from the previous get_markets call
                    'event_ticker': None,
                    'series_ticker': None,
                    'max_close_ts': None, # pass in unix_ts
                    'min_close_ts': None, # pass in unix_ts
                    'status': None,
                    'tickers':None}

markets_response = exchange_client.get_markets(**market_params)
cursor = markets_response['cursor']

print('keys:', markets_response.keys())
print()
print('number of objects:', len(markets_response['markets'])) # 100 objects!
print()
print('first market in market_response payload:', markets_response['markets'][0]) # new markets!
print()
print('new cursor!', cursor)
# Out:
# keys: dict_keys(['markets', 'cursor'])
#
# number of objects: 100
#
# first market in market_response payload: {'ticker': 'KXSPOTIFYAUSTRALIAD-25MAY24-THA', 'event_ticker': 'KXSPOTIFYAUSTRALIAD-25MAY24', 'market_type': 'binary', 'title': 'Top Song on Daily Top Songs Australia on May 24, 2025?', 'subtitle': ':: Gracie Abrams', 'yes_sub_title': 'That’s So True', 'no_sub_title': 'That’s So True', 'open_time': '2025-05-23T21:00:00Z', 'close_time': '2025-05-25T03:59:00Z', 'expected_expiration_time': '2025-06-07T14:00:00Z', 'expiration_time': '2025-06-07T14:00:00Z', 'latest_expiration_time': '2025-06-07T14:00:00Z', 'settlement_timer_seconds': 300, 'status': 'initialized', 'response_price_units': 'usd_cent', 'notional_value': 100, 'tick_size': 1, 'yes_bid': 0, 'yes_ask': 0, 'no_bid': 100, 'no_ask': 100, 'last_price': 0, 'previous_yes_bid': 0, 'previous_yes_ask': 0, 'previous_price': 0, 'volume': 0, 'volume_24h': 0, 'liquidity': 0, 'open_interest': 0, 'result': '', 'can_close_early': True, 'expiration_value': '', 'category': '', 'risk_limit_cents': 0, 'strike_type': 'custom', 'custom_strike': {'Song/Artist/Album': 'That’s So True'}, 'rules_primary': '', 'rules_secondary': ''}
#
# new cursor! CgwI7o3CwQYQ2Mr8hgISHEtYU1BPVElGWUdMT0JBTEQtMjVNQVkyNC1XSUw

# %%
# Next, let's look at event level data by passing an event ticker to the get_event endpoint...

event_ticker = markets_response['markets'][5]['event_ticker']
event_params = {'event_ticker': event_ticker}
event_response = exchange_client.get_event(**event_params)

print('keys:', event_response.keys())
print()
print('event object:', event_response['event'])
print()
print('first market in event_response payload:', event_response['markets'][0])
# Out:
# keys: dict_keys(['event', 'markets'])
#
# event object: {'event_ticker': 'KXSPOTIFYAUSTRALIAD-25MAY24', 'series_ticker': 'KXSPOTIFYAUSTRALIAD', 'sub_title': 'On May 24, 2025 Chart', 'title': 'Top Song on Daily Top Songs Australia tomorrow?', 'collateral_return_type': 'MECNET', 'mutually_exclusive': True, 'category': 'Entertainment'}
#
# first market in event_response payload: {'ticker': 'KXSPOTIFYAUSTRALIAD-25MAY24-ORD', 'event_ticker': 'KXSPOTIFYAUSTRALIAD-25MAY24', 'market_type': 'binary', 'title': '', 'subtitle': ':: Alex Warren', 'yes_sub_title': 'Ordinary', 'no_sub_title': 'Ordinary', 'open_time': '2025-05-23T21:00:00Z', 'close_time': '2025-05-25T03:59:00Z', 'expected_expiration_time': '2025-06-07T14:00:00Z', 'expiration_time': '2025-06-07T14:00:00Z', 'latest_expiration_time': '2025-06-07T14:00:00Z', 'settlement_timer_seconds': 300, 'status': 'initialized', 'response_price_units': 'usd_cent', 'notional_value': 100, 'tick_size': 1, 'yes_bid': 0, 'yes_ask': 0, 'no_bid': 100, 'no_ask': 100, 'last_price': 0, 'previous_yes_bid': 0, 'previous_yes_ask': 0, 'previous_price': 0, 'volume': 0, 'volume_24h': 0, 'liquidity': 0, 'open_interest': 0, 'result': '', 'can_close_early': True, 'expiration_value': '', 'category': '', 'risk_limit_cents': 0, 'strike_type': 'custom', 'custom_strike': {'Song/Artist/Album': 'Ordinary'}, 'rules_primary': '', 'rules_secondary': ''}

# %%
# Next, let's look at series level data by passing a series ticker to the get_series endpoint! 
series_ticker = event_response['event']['series_ticker']
series_params = {'series_ticker': series_ticker}
series_response = exchange_client.get_series(**series_params)

print('keys:', series_response.keys())
print()
print('series object:', series_response['series'])
print()
# Out:
# keys: dict_keys(['series'])
#
# series object: {'ticker': 'KXSPOTIFYAUSTRALIAD', 'frequency': 'daily', 'title': 'Daily Australia Spotify songs', 'category': 'Entertainment', 'tags': ['Music', 'Music charts'], 'settlement_sources': [{'url': 'https://charts.spotify.com/home', 'name': 'Spotify Charts'}], 'contract_url': 'https://kalshi-public-docs.s3.us-east-1.amazonaws.com/regulatory/product-certifications/SPOTIFYCHART.pdf'}

# %%
# Next let's look at the recent market history for a market
series_ticker = 'KXLLM1'
ticker =        'KXLLM1-25MAY31-GOOG'

market_history_params = {
    'series_ticker':    series_ticker,
    'market_ticker':    ticker,
    'period_interval':  1, # 1 minute candlesticks
    'start_ts':         int(time.time()) - 60 * 60 * 24 * 1, # passing a recent unix_ts
    'end_ts':           int(time.time()),         # passing a recent unix_ts
}
market_history_response = exchange_client.get_market_history(**market_history_params)

print(market_history_response)

print('keys:', market_history_response.keys())
print()
print('most recent market history object:', market_history_response['candlesticks'][-1])
print()

# and then also look at the most current view of the orderbook
market_history_params = {
    'ticker': ticker,
    'depth':  30
}
orderbook_response = exchange_client.get_orderbook(**market_history_params)

print('keys:', orderbook_response.keys())
print()
print('orderbook object:', orderbook_response)
print()
# Out:
# {'ticker': 'KXLLM1-25MAY31-GOOG', 'candlesticks': [{'end_period_ts': 1747951800, 'yes_bid': {'open': 0, 'low': 0, 'high': 0, 'close': 0}, 'yes_ask': {'open': 10, 'low': 10, 'high': 100, 'close': 100}, 'price': {'open': None, 'low': None, 'high': None, 'close': None, 'mean': None, 'previous': None}, 'volume': 0, 'open_interest': 0}]}
# keys: dict_keys(['ticker', 'candlesticks'])
#
# most recent market history object: {'end_period_ts': 1747951800, 'yes_bid': {'open': 0, 'low': 0, 'high': 0, 'close': 0}, 'yes_ask': {'open': 10, 'low': 10, 'high': 100, 'close': 100}, 'price': {'open': None, 'low': None, 'high': None, 'close': None, 'mean': None, 'previous': None}, 'volume': 0, 'open_interest': 0}
#
# keys: dict_keys(['orderbook'])
#
# orderbook object: {'orderbook': {'yes': None, 'no': None}}

# %%
# Now let's suppose we wanted to place a trade on one of these markets...
# to do so, we would first want to check out available balance...

current_balance = exchange_client.get_balance()
current_balance
# Out:
# {'balance': 385003}

# %%
# Now that you have some balance, you might want to see how your current positions are doing...

positions_params = {
    'limit': None,
    'cursor': None,
    'settlement_status': None,
    'ticker': None,
    'event_ticker': None,
}

current_position = exchange_client.get_positions(**positions_params)
current_position
# Out:
# {'cursor': '',
#  'market_positions': [{'ticker': 'BTCMAXY-24DEC31-90000',
#    'total_traded': 5100,
#    'position': 100,
#    'market_exposure': 5100,
#    'realized_pnl': 0,
#    'resting_orders_count': 0,
#    'fees_paid': 175,
#    'last_updated_ts': '2024-06-03T18:04:41.052476Z'},
#   {'ticker': 'BTCMAXY-24DEC31-80000',
#    'total_traded': 9450,
#    'position': 150,
#    'market_exposure': 9450,
#    'realized_pnl': 0,
#    'resting_orders_count': 0,
#    'fees_paid': 80,
#    'last_updated_ts': '2024-07-31T20:13:10.833106Z'},
#   {'ticker': 'LLM1-24DEC31-OAI',
#    'total_traded': 1206,
#    'position': 21,
#    'market_exposure': 1206,
#    'realized_pnl': 0,
#    'resting_orders_count': 0,
#    'fees_paid': 17,
#    'last_updated_ts': '2024-06-20T22:39:35.771596Z'},
#   {'ticker': 'LLM1-24DEC31-A',
#    'total_traded': 1950,
#    'position': 50,
#    'market_exposure': 1950,
#    'realized_pnl': 0,
#    'resting_orders_count': 0,
#    'fees_paid': 84,
#    'last_updated_ts': '2024-07-29T15:07:29.283082Z'},
#   {'ticker': 'CPICORE-24JUN-T0.1',
#    'total_traded': 5700,
#    'position': 0,
#    'market_exposure': 0,
#    'realized_pnl': -5700,
#    'resting_orders_count': 0,
#    'fees_paid': 172,
#    'last_updated_ts': '2024-07-11T15:55:33.781078Z'},
#   {'ticker': 'ACPI-24-B3.5',
#    'total_traded': 5100,
#    'position': 100,
#    'market_exposure': 5100,
#    'realized_pnl': 0,
#    'resting_orders_count': 0,
#    'fees_paid': 175,
#    'last_updated_ts': '2024-06-21T15:04:57.063233Z'},
#   {'ticker': 'ACPICORE-24-B3.5',
#    'total_traded': 6300,
#    'position': 100,
#    'market_exposure': 6300,
#    'realized_pnl': 0,
#    'resting_orders_count': 0,
#    'fees_paid': 164,
#    'last_updated_ts': '2024-06-18T21:35:18.921885Z'},
#   {'ticker': 'CREDITCDEF-24-Q1-3.10',
#    'total_traded': 930,
#    'position': 0,
#    'market_exposure': 0,
#    'realized_pnl': 70,
#    'resting_orders_count': 0,
#    'fees_paid': 5,
#    'last_updated_ts': '2024-05-30T14:04:32.307245Z'},
#   {'ticker': 'NASDAQ100Y-24DEC31-B13750',
#    'total_traded': 1,
#    'position': -1,
#    'market_exposure': 1,
#    'realized_pnl': 0,
#    'resting_orders_count': 0,
#    'fees_paid': 1,
#    'last_updated_ts': '2024-05-02T19:12:20.488391Z'},
#   {'ticker': 'NASDAQ100Y-24DEC31-T18499.99',
#    'total_traded': 6148,
#    'position': 46,
#    'market_exposure': 1196,
#    'realized_pnl': 48,
#    'resting_orders_count': 0,
#    'fees_paid': 67,
#    'last_updated_ts': '2024-01-18T14:30:37.612778Z'},
#   {'ticker': 'RATECUT-24MAY01',
#    'total_traded': 366,
#    'position': 0,
#    'market_exposure': 0,
#    'realized_pnl': -366,
#    'resting_orders_count': 0,
#    'fees_paid': 0,
#    'last_updated_ts': '2024-05-02T15:48:13.74241Z'},
#   {'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'total_traded': 25000,
#    'position': -500,
#    'market_exposure': 25000,
#    'realized_pnl': 0,
#    'resting_orders_count': 0,
#    'fees_paid': 0,
#    'last_updated_ts': '2024-05-01T03:30:39.898419Z'},
#   {'ticker': 'PAYROLLS-24MAR-T225000',
#    'total_traded': 301,
#    'position': 0,
#    'market_exposure': 0,
#    'realized_pnl': -301,
#    'resting_orders_count': 0,
#    'fees_paid': 1,
#    'last_updated_ts': '2024-04-05T15:06:27.973484Z'},
#   {'ticker': 'RATECUT-24MAR20',
#    'total_traded': 4826,
#    'position': 0,
#    'market_exposure': 0,
#    'realized_pnl': 3374,
#    'resting_orders_count': 0,
#    'fees_paid': 140,
#    'last_updated_ts': '2024-03-21T16:06:17.372081Z'},
#   {'ticker': 'FED-24MAR-T5.25',
#    'total_traded': 21251,
#    'position': 0,
#    'market_exposure': 0,
#    'realized_pnl': -20451,
#    'resting_orders_count': 0,
#    'fees_paid': 14,
#    'last_updated_ts': '2024-03-20T18:06:25.271253Z'},
#   {'ticker': 'FED-24MAR-T4.50',
#    'total_traded': 62737,
#    'position': 0,
#    'market_exposure': 0,
#    'realized_pnl': -62737,
#    'resting_orders_count': 0,
#    'fees_paid': 643,
#    'last_updated_ts': '2024-03-20T18:06:01.281098Z'},
#   {'ticker': 'OSCARASPLAY-24-KOTFM',
#    'total_traded': 0,
#    'position': 0,
#    'market_exposure': 0,
#    'realized_pnl': 0,
#    'resting_orders_count': 0,
#    'fees_paid': 0,
#    'last_updated_ts': '2024-03-11T15:05:16.58094Z'},
#   {'ticker': 'OSCARSUPACTR-24-EB',
#    'total_traded': 1720,
#    'position': 0,
#    'market_exposure': 0,
#    'realized_pnl': 280,
#    'resting_orders_count': 0,
#    'fees_paid': 17,
#    'last_updated_ts': '2024-03-11T15:01:27.511259Z'},
#   {'ticker': 'CREDITCDEF-23-Q4-2.98',
#    'total_traded': 200,
#    'position': 0,
#    'market_exposure': 0,
#    'realized_pnl': 300,
#    'resting_orders_count': 0,
#    'fees_paid': 0,
#    'last_updated_ts': '2024-02-23T21:58:15.795302Z'},
#   {'ticker': 'ARGINFLATIONM-24JAN-T150',
#    'total_traded': 51,
#    'position': 0,
#    'market_exposure': 0,
#    'realized_pnl': -51,
#    'resting_orders_count': 0,
#    'fees_paid': 1,
#    'last_updated_ts': '2024-02-20T22:21:29.780899Z'},
#   {'ticker': 'GRAMAOTY-66-M',
#    'total_traded': 0,
#    'position': 0,
#    'market_exposure': 0,
#    'realized_pnl': 0,
#    'resting_orders_count': 0,
#    'fees_paid': 0,
#    'last_updated_ts': '2024-02-05T16:02:00.832166Z'},
#   {'ticker': 'GRAMAOTY-66-TR',
#    'total_traded': 0,
#    'position': 0,
#    'market_exposure': 0,
#    'realized_pnl': 0,
#    'resting_orders_count': 0,
#    'fees_paid': 0,
#    'last_updated_ts': '2024-02-05T16:02:00.832166Z'},
#   {'ticker': 'GRAMAOTY-66-S',
#    'total_traded': 0,
#    'position': 0,
#    'market_exposure': 0,
#    'realized_pnl': 0,
#    'resting_orders_count': 0,
#    'fees_paid': 0,
#    'last_updated_ts': '2024-02-05T16:02:00.832166Z'},
#   {'ticker': 'TERMINALRATE-23DEC31-B5.745',
#    'total_traded': 2358,
#    'position': 0,
#    'market_exposure': 0,
#    'realized_pnl': 242,
#    'resting_orders_count': 0,
#    'fees_paid': 16,
#    'last_updated_ts': '2024-01-04T15:19:56.879127Z'},
#   {'ticker': 'TERMINALRATE-23DEC31-B6.120',
#    'total_traded': 0,
#    'position': 0,
#    'market_exposure': 0,
#    'realized_pnl': 0,
#    'resting_orders_count': 0,
#    'fees_paid': 0,
#    'last_updated_ts': '2024-01-04T15:19:56.879127Z'}],
#  'event_positions': [{'event_ticker': 'BTCMAXY-24DEC31',
#    'total_cost': 14550,
#    'event_exposure': 14550,
#    'realized_pnl': 0,
#    'resting_order_count': 0,
#    'fees_paid': 255},
#   {'event_ticker': 'LLM1-24DEC31',
#    'total_cost': 3156,
#    'event_exposure': 3156,
#    'realized_pnl': 0,
#    'resting_order_count': 0,
#    'fees_paid': 101},
#   {'event_ticker': 'CPICORE-24JUN',
#    'total_cost': 5700,
#    'event_exposure': 0,
#    'realized_pnl': -5700,
#    'resting_order_count': 0,
#    'fees_paid': 172},
#   {'event_ticker': 'ACPI-2024',
#    'total_cost': 5100,
#    'event_exposure': 5100,
#    'realized_pnl': 0,
#    'resting_order_count': 0,
#    'fees_paid': 175},
#   {'event_ticker': 'ACPICORE-2024',
#    'total_cost': 6300,
#    'event_exposure': 6300,
#    'realized_pnl': 0,
#    'resting_order_count': 0,
#    'fees_paid': 164},
#   {'event_ticker': 'CREDITCDEF-24-Q1',
#    'total_cost': 930,
#    'event_exposure': 0,
#    'realized_pnl': 70,
#    'resting_order_count': 0,
#    'fees_paid': 5},
#   {'event_ticker': 'NASDAQ100Y-24DEC31',
#    'total_cost': 6149,
#    'event_exposure': 1197,
#    'realized_pnl': 48,
#    'resting_order_count': 0,
#    'fees_paid': 68},
#   {'event_ticker': 'RATECUT-24MAY01',
#    'total_cost': 366,
#    'event_exposure': 0,
#    'realized_pnl': -366,
#    'resting_order_count': 0,
#    'fees_paid': 0},
#   {'event_ticker': 'TOPALBUMYEAR-24',
#    'total_cost': 25000,
#    'event_exposure': 25000,
#    'realized_pnl': 0,
#    'resting_order_count': 0,
#    'fees_paid': 0},
#   {'event_ticker': 'PAYROLLS-24MAR',
#    'total_cost': 301,
#    'event_exposure': 0,
#    'realized_pnl': -301,
#    'resting_order_count': 0,
#    'fees_paid': 1},
#   {'event_ticker': 'RATECUT-24MAR20',
#    'total_cost': 4826,
#    'event_exposure': 0,
#    'realized_pnl': 3374,
#    'resting_order_count': 0,
#    'fees_paid': 140},
#   {'event_ticker': 'FED-24MAR',
#    'total_cost': 83988,
#    'event_exposure': 0,
#    'realized_pnl': -83188,
#    'resting_order_count': 0,
#    'fees_paid': 657},
#   {'event_ticker': 'OSCARASPLAY-24',
#    'total_cost': 0,
#    'event_exposure': 0,
#    'realized_pnl': 0,
#    'resting_order_count': 0,
#    'fees_paid': 0},
#   {'event_ticker': 'OSCARSUPACTR-24',
#    'total_cost': 1720,
#    'event_exposure': 0,
#    'realized_pnl': 280,
#    'resting_order_count': 0,
#    'fees_paid': 17},
#   {'event_ticker': 'CREDITCDEF-23-Q4',
#    'total_cost': 200,
#    'event_exposure': 0,
#    'realized_pnl': 300,
#    'resting_order_count': 0,
#    'fees_paid': 0},
#   {'event_ticker': 'ARGINFLATIONM-24JAN',
#    'total_cost': 51,
#    'event_exposure': 0,
#    'realized_pnl': -51,
#    'resting_order_count': 0,
#    'fees_paid': 1},
#   {'event_ticker': 'GRAMAOTY-66',
#    'total_cost': 0,
#    'event_exposure': 0,
#    'realized_pnl': 0,
#    'resting_order_count': 0,
#    'fees_paid': 0},
#   {'event_ticker': 'TERMINALRATE-23DEC31',
#    'total_cost': 2358,
#    'event_exposure': 0,
#    'realized_pnl': 242,
#    'resting_order_count': 0,
#    'fees_paid': 16}]}

# %%
# seems like some of your recent orders had been filled. To check on those we use the get_positions endpoint ...

fills_params = {
    'ticker':   None,
    'order_id': None,
    'min_ts':   None,
    'max_ts':   None,
    'limit':    None,
    'cursor':   None,
}

fills = exchange_client.get_fills(**fills_params)
fills
# Out:
# {'fills': [{'trade_id': '05c03cc5-7fcd-4158-8415-f59fa6238101',
#    'ticker': 'KXBTCMAXY-25-DEC31-124999.99',
#    'order_id': 'a630bbae-7596-4ce0-8645-37ae719cd3c0',
#    'side': 'yes',
#    'action': 'sell',
#    'count': 2,
#    'yes_price': 65,
#    'no_price': 35,
#    'is_taker': True,
#    'created_time': '2025-05-22T12:12:03.313608Z'},
#   {'trade_id': '3d082b2f-31a2-490a-ab10-1a0f615687b6',
#    'ticker': 'KXBTCMAXY-25-DEC31-124999.99',
#    'order_id': '8596a175-c94c-42d6-9fde-64f9b9463cf4',
#    'side': 'no',
#    'action': 'buy',
#    'count': 2,
#    'yes_price': 60,
#    'no_price': 40,
#    'is_taker': True,
#    'created_time': '2025-05-22T12:10:35.472077Z'},
#   {'trade_id': '06f1ced2-b5ec-4046-9327-ad6a4b7c6619',
#    'ticker': 'KXDOGEMAX1-25-JUN01-0.99999999',
#    'order_id': '555d4554-8263-4b80-a2ba-9ea3d70e737b',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 12,
#    'no_price': 88,
#    'is_taker': True,
#    'created_time': '2025-05-21T00:05:43.087383Z'},
#   {'trade_id': 'bc23c077-4dc7-489b-bead-f6ee38a058d8',
#    'ticker': 'KXDOGEMAX1-25-JUN01-0.99999999',
#    'order_id': 'fde20a8b-330e-4e20-823d-951263329c96',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 12,
#    'no_price': 88,
#    'is_taker': True,
#    'created_time': '2025-05-21T00:05:23.534153Z'},
#   {'trade_id': '38cbf55c-6ded-41f3-9a3f-ef62c1e592ff',
#    'ticker': 'KXDOGEMAX1-25-JUN01-0.99999999',
#    'order_id': '9b554bfb-892e-444c-9296-082830950530',
#    'side': 'yes',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 18,
#    'no_price': 82,
#    'is_taker': True,
#    'created_time': '2025-05-21T00:04:29.301238Z'},
#   {'trade_id': 'abc66ec3-fdc8-463f-8553-e5a48271431d',
#    'ticker': 'KXDOGEMAX1-25-JUN01-0.99999999',
#    'order_id': 'e9151d67-6525-413c-bc42-785eef0f05ec',
#    'side': 'yes',
#    'action': 'sell',
#    'count': 1,
#    'yes_price': 18,
#    'no_price': 82,
#    'is_taker': True,
#    'created_time': '2025-05-20T23:59:57.526557Z'},
#   {'trade_id': '9d88f5e5-6466-4325-9b6a-60a5469cd5bd',
#    'ticker': 'KXDOGEMAX1-25-JUN01-0.99999999',
#    'order_id': '828ff9db-f5cf-4f97-b39e-e5a5d5c9f911',
#    'side': 'yes',
#    'action': 'sell',
#    'count': 1,
#    'yes_price': 18,
#    'no_price': 82,
#    'is_taker': True,
#    'created_time': '2025-05-20T23:57:57.902944Z'},
#   {'trade_id': '75e45edb-05c4-411d-944a-e0580f455985',
#    'ticker': 'KXDOGEMAX1-25-JUN01-0.99999999',
#    'order_id': '90c9cf94-fa16-4d49-bd84-1f8f2d64700e',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 12,
#    'no_price': 88,
#    'is_taker': True,
#    'created_time': '2025-05-20T23:55:07.457629Z'},
#   {'trade_id': '8b5b68a0-b546-4d12-87fe-5b0722008992',
#    'ticker': 'KXDOGEMAX1-25-JUN01-0.99999999',
#    'order_id': '7ec4676a-1a10-45e3-a0f1-090ccdd1ee37',
#    'side': 'yes',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 13,
#    'no_price': 87,
#    'is_taker': False,
#    'created_time': '2025-05-20T23:54:56.926909Z'},
#   {'trade_id': 'f6150f7b-35b9-411b-8d87-8d70b1d22d44',
#    'ticker': 'KXDOGEMAX1-25-JUN01-0.99999999',
#    'order_id': '69a25df6-d636-4572-9223-2058712f9390',
#    'side': 'no',
#    'action': 'buy',
#    'count': 3,
#    'yes_price': 12,
#    'no_price': 88,
#    'is_taker': True,
#    'created_time': '2025-05-20T23:43:12.977652Z'},
#   {'trade_id': '4fe0e95b-2c65-4374-a5d4-bc9c68053f64',
#    'ticker': 'KXNCAAMBPS-25R2G5-NCAT',
#    'order_id': 'd09c66cc-8cb0-4304-b062-62a2f118976d',
#    'side': 'yes',
#    'action': 'buy',
#    'count': 29,
#    'yes_price': 90,
#    'no_price': 10,
#    'is_taker': False,
#    'created_time': '2025-04-16T19:11:15.56725Z'},
#   {'trade_id': 'a59c183d-767c-44e2-bb22-13abed2edd72',
#    'ticker': 'APPLEUS-29DEC31',
#    'order_id': '46112c0a-64e3-4fd3-8e26-a5ee7d7939c8',
#    'side': 'yes',
#    'action': 'sell',
#    'count': 2,
#    'yes_price': 38,
#    'no_price': 62,
#    'is_taker': True,
#    'created_time': '2025-04-09T20:43:29.369549Z'},
#   {'trade_id': '459be560-4f08-4077-8da4-5006f8912eb0',
#    'ticker': 'APPLEUS-29DEC31',
#    'order_id': '46112c0a-64e3-4fd3-8e26-a5ee7d7939c8',
#    'side': 'yes',
#    'action': 'sell',
#    'count': 8,
#    'yes_price': 38,
#    'no_price': 62,
#    'is_taker': True,
#    'created_time': '2025-04-09T20:43:29.369549Z'},
#   {'trade_id': 'a4c33ca2-0591-4e79-be05-c4d6ee7f5f0e',
#    'ticker': 'KXASL3-27',
#    'order_id': '6e04dbbf-c615-4417-8bbc-bcb60e24b6a1',
#    'side': 'yes',
#    'action': 'buy',
#    'count': 5,
#    'yes_price': 23,
#    'no_price': 77,
#    'is_taker': True,
#    'created_time': '2025-03-17T20:59:39.281932Z'},
#   {'trade_id': 'b3f0a304-093f-4531-9d62-036915c2025a',
#    'ticker': 'KXTRUMPPARDON-25MAY01-EA',
#    'order_id': '278805e6-1147-40b3-90a7-d06c4246f068',
#    'side': 'yes',
#    'action': 'sell',
#    'count': 1,
#    'yes_price': 30,
#    'no_price': 70,
#    'is_taker': True,
#    'created_time': '2025-03-17T02:11:58.151161Z'},
#   {'trade_id': '374975aa-d9da-4bf4-8406-2f72193fac43',
#    'ticker': 'KXTRUMPPARDON-25MAY01-EA',
#    'order_id': 'fc3bcfc8-af89-4cbb-8f7e-f2a4359f12c3',
#    'side': 'no',
#    'action': 'buy',
#    'count': 5,
#    'yes_price': 27,
#    'no_price': 73,
#    'is_taker': True,
#    'created_time': '2025-03-17T02:08:09.894051Z'},
#   {'trade_id': 'f6d9847f-fe3a-4225-b73a-f27c8a59668b',
#    'ticker': 'KXTRUMPPARDON-25MAY01-SB',
#    'order_id': 'f84d09f9-99fc-4f9a-b700-dda875781f21',
#    'side': 'no',
#    'action': 'buy',
#    'count': 5,
#    'yes_price': 40,
#    'no_price': 60,
#    'is_taker': True,
#    'created_time': '2025-03-17T02:07:19.182571Z'},
#   {'trade_id': '33c9d724-5670-4b68-a06c-1c5f4a439a37',
#    'ticker': 'KXNCAAMBPS-25R2G5-NCAT',
#    'order_id': 'd09c66cc-8cb0-4304-b062-62a2f118976d',
#    'side': 'yes',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 90,
#    'no_price': 10,
#    'is_taker': False,
#    'created_time': '2025-03-17T00:18:09.508548Z'},
#   {'trade_id': '40d503ec-affa-441b-b214-167a7fc86d82',
#    'ticker': 'KXNCAAMBPS-25R2G9-UPRV',
#    'order_id': '11398d82-df19-409e-96ca-b6ea6db965bd',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 1,
#    'no_price': 99,
#    'is_taker': True,
#    'created_time': '2025-03-17T00:17:11.728571Z'},
#   {'trade_id': 'c3f9356b-ab02-4a84-ba57-8db4245c20ac',
#    'ticker': 'KXNCAAMBPS-25R2G5-NCAT',
#    'order_id': 'd09c66cc-8cb0-4304-b062-62a2f118976d',
#    'side': 'yes',
#    'action': 'buy',
#    'count': 9,
#    'yes_price': 90,
#    'no_price': 10,
#    'is_taker': False,
#    'created_time': '2025-03-17T00:15:58.984971Z'},
#   {'trade_id': '58f3440e-a997-4900-afc0-067926968b12',
#    'ticker': 'KXNCAAMBPS-25R2G9-UPRV',
#    'order_id': 'db6a3273-feeb-4700-9de0-8a6cf6e66665',
#    'side': 'no',
#    'action': 'buy',
#    'count': 50,
#    'yes_price': 1,
#    'no_price': 99,
#    'is_taker': True,
#    'created_time': '2025-03-16T23:31:53.081274Z'},
#   {'trade_id': '93631baa-0c70-4bf5-891b-455acbca7850',
#    'ticker': 'KXNCAAMBPS-25R2G5-NCAT',
#    'order_id': 'd09c66cc-8cb0-4304-b062-62a2f118976d',
#    'side': 'yes',
#    'action': 'buy',
#    'count': 9,
#    'yes_price': 90,
#    'no_price': 10,
#    'is_taker': False,
#    'created_time': '2025-03-16T23:28:13.702426Z'},
#   {'trade_id': '04f6f429-de4d-44c4-a000-67a1e34e0023',
#    'ticker': 'KXNCAAMBPS-25R2G5-NCAT',
#    'order_id': 'd09c66cc-8cb0-4304-b062-62a2f118976d',
#    'side': 'yes',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 90,
#    'no_price': 10,
#    'is_taker': False,
#    'created_time': '2025-03-16T23:26:33.762008Z'},
#   {'trade_id': '9a8516cb-b2f1-408e-b0f6-0af2416b3447',
#    'ticker': 'KXNCAAMBPS-25R2G5-NCAT',
#    'order_id': 'd09c66cc-8cb0-4304-b062-62a2f118976d',
#    'side': 'yes',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 90,
#    'no_price': 10,
#    'is_taker': False,
#    'created_time': '2025-03-16T23:26:17.398774Z'},
#   {'trade_id': '57d60d5c-3195-4506-91ae-7895f15eff48',
#    'ticker': 'KXOSCARNOMINEESPIC-25-(B)(DP2)(F)(G2)(JFAD)(KOK)(M)(M17)(SS)(WLIT)',
#    'order_id': '8449f811-b626-4321-be78-b3534791f9bf',
#    'side': 'yes',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 60,
#    'no_price': 40,
#    'is_taker': True,
#    'created_time': '2025-01-13T17:44:12.176553Z'},
#   {'trade_id': 'c9b31d08-5af6-4975-9ed4-a75261d649a9',
#    'ticker': 'KXGRAMMYWINNERS-67AOTYXXSOTY-TTPDXXBOAF',
#    'order_id': '270f63d2-4978-4bd3-b0b1-5c479abdf8da',
#    'side': 'yes',
#    'action': 'buy',
#    'count': 11,
#    'yes_price': 8,
#    'no_price': 92,
#    'is_taker': True,
#    'created_time': '2025-01-13T17:22:50.880169Z'},
#   {'trade_id': 'd6120ae2-0793-492f-9b39-ea484e653cca',
#    'ticker': 'KXGRAMMYWINNERS-67AOTYXXSOTY-TTPDXXBOAF',
#    'order_id': '084bbc60-c54e-451e-9723-30a3efac54e1',
#    'side': 'yes',
#    'action': 'buy',
#    'count': 11,
#    'yes_price': 8,
#    'no_price': 92,
#    'is_taker': True,
#    'created_time': '2025-01-13T17:17:35.246149Z'},
#   {'trade_id': 'bed54696-4fcc-45e5-ab2a-cc1cf3c0fb65',
#    'ticker': 'KXGRAMMYWINNERS-67AOTYXXROTY-CCXXNLU',
#    'order_id': '5ee04abf-5e10-4d59-b316-243c62aa05cf',
#    'side': 'yes',
#    'action': 'buy',
#    'count': 46,
#    'yes_price': 2,
#    'no_price': 98,
#    'is_taker': True,
#    'created_time': '2025-01-13T16:53:27.276882Z'},
#   {'trade_id': '38e77118-96ef-4355-9a61-5bd4f5c41938',
#    'ticker': 'ROBOTAXIOUT-26-JAN01',
#    'order_id': 'af22affd-a4a8-4db9-aaf4-384c1c42aa2f',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 32,
#    'no_price': 68,
#    'is_taker': True,
#    'created_time': '2025-01-13T15:12:34.321716Z'},
#   {'trade_id': '349e60e2-7164-43ef-9c8e-a835d7cbec14',
#    'ticker': 'ROBOTAXIOUT-26-JAN01',
#    'order_id': '1c7fc655-a678-4503-8aa9-f7e43378389c',
#    'side': 'yes',
#    'action': 'sell',
#    'count': 1,
#    'yes_price': 40,
#    'no_price': 60,
#    'is_taker': True,
#    'created_time': '2025-01-06T21:35:26.303659Z'},
#   {'trade_id': '065f1fe7-9290-4cec-bd94-c022dcc8ece6',
#    'ticker': 'KXFEDEND-29-JAN20',
#    'order_id': '133b3f9e-d6d1-4529-a3c0-58e654afcc26',
#    'side': 'yes',
#    'action': 'buy',
#    'count': 39,
#    'yes_price': 12,
#    'no_price': 88,
#    'is_taker': True,
#    'created_time': '2025-01-05T05:15:10.611181Z'},
#   {'trade_id': 'f5f6af3d-69d8-4676-9e5b-3dea4aa73ac4',
#    'ticker': 'KXLARGETARIFF',
#    'order_id': 'c2471c07-326c-4707-8325-89c2efbb2fe2',
#    'side': 'yes',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 57,
#    'no_price': 43,
#    'is_taker': True,
#    'created_time': '2025-01-05T05:06:50.505954Z'},
#   {'trade_id': 'd67e94e0-576b-4b59-81d8-5f0e69a35be0',
#    'ticker': 'KXLARGETARIFF',
#    'order_id': 'c2471c07-326c-4707-8325-89c2efbb2fe2',
#    'side': 'yes',
#    'action': 'buy',
#    'count': 2,
#    'yes_price': 57,
#    'no_price': 43,
#    'is_taker': True,
#    'created_time': '2025-01-05T05:06:50.505954Z'},
#   {'trade_id': 'b075d59c-925b-4fed-9940-a18f28aa740c',
#    'ticker': 'KXSECTREASURY-26DEC31-SB',
#    'order_id': '9e722a48-ffe2-4fb4-ad2c-04b0e1b7637a',
#    'side': 'yes',
#    'action': 'buy',
#    'count': 2,
#    'yes_price': 97,
#    'no_price': 3,
#    'is_taker': True,
#    'created_time': '2025-01-05T05:01:48.689952Z'},
#   {'trade_id': '372a8f6e-c2a2-4660-a387-697105e010cf',
#    'ticker': 'KXOSCARNOMINEESPIC-25-(B)(DP2)(F)(G2)(JFAD)(KOK)(M)(M17)(SS)(WLIT)',
#    'order_id': '33bc994f-d929-4500-a82c-6e95fe5c5714',
#    'side': 'yes',
#    'action': 'buy',
#    'count': 935,
#    'yes_price': 1,
#    'no_price': 99,
#    'is_taker': True,
#    'created_time': '2025-01-03T16:40:12.709606Z'},
#   {'trade_id': 'e79f2999-c154-467d-83fc-f1bc366edcba',
#    'ticker': 'KXOSCARNOMINEESPIC-25-(B)(DP2)(F)(G2)(JFAD)(KOK)(M)(M17)(SS)(WLIT)',
#    'order_id': 'f88e5390-973c-4f18-b9e6-cd9efeef29fd',
#    'side': 'yes',
#    'action': 'buy',
#    'count': 3,
#    'yes_price': 60,
#    'no_price': 40,
#    'is_taker': True,
#    'created_time': '2025-01-02T16:13:41.039413Z'},
#   {'trade_id': '71a298f8-0e59-49c8-abb6-3a2bdafca8bd',
#    'ticker': 'KXGRAMMYWINNERS-67AOTYXXROTY-CCXXNLU',
#    'order_id': 'af6a83c4-817c-4988-85fa-211d475e7776',
#    'side': 'yes',
#    'action': 'buy',
#    'count': 2,
#    'yes_price': 10,
#    'no_price': 90,
#    'is_taker': True,
#    'created_time': '2024-12-30T02:45:52.265711Z'},
#   {'trade_id': 'e7a84bcf-ec52-4ed4-a7de-92326641a88b',
#    'ticker': 'KXGRAMMYWINNERS-67AOTYXXROTY-CCXXNLU',
#    'order_id': '8f31413e-223e-4166-857e-323522a5ae1f',
#    'side': 'yes',
#    'action': 'buy',
#    'count': 2,
#    'yes_price': 10,
#    'no_price': 90,
#    'is_taker': True,
#    'created_time': '2024-12-29T20:39:21.789266Z'},
#   {'trade_id': '63e54d70-32a2-4707-9018-a26d613a716f',
#    'ticker': 'KXGRAMMYWINNERS-67AOTYXXROTY-CCXXNLU',
#    'order_id': '70622fcd-3fcc-4aad-a0b1-fc352423ecdc',
#    'side': 'yes',
#    'action': 'buy',
#    'count': 3,
#    'yes_price': 10,
#    'no_price': 90,
#    'is_taker': True,
#    'created_time': '2024-12-29T20:34:46.899471Z'},
#   {'trade_id': '8744d5b0-5a25-4d6b-a801-d7dba2430e2d',
#    'ticker': 'KXGRAMMYWINNERS-67AOTYXXROTY-CCXXNLU',
#    'order_id': 'a338ad2b-2587-410d-9a8e-bac17a9fece9',
#    'side': 'yes',
#    'action': 'buy',
#    'count': 5,
#    'yes_price': 10,
#    'no_price': 90,
#    'is_taker': True,
#    'created_time': '2024-12-29T19:43:10.209429Z'},
#   {'trade_id': 'f59c61d7-c632-45ce-9174-153af8b87bf7',
#    'ticker': 'KXGRAMMYWINNERS-67AOTYXXROTY-CCXXNLU',
#    'order_id': '545d6952-d9cc-4685-96c3-67f727d12a67',
#    'side': 'yes',
#    'action': 'buy',
#    'count': 20,
#    'yes_price': 10,
#    'no_price': 90,
#    'is_taker': True,
#    'created_time': '2024-12-27T04:23:50.024259Z'},
#   {'trade_id': 'e6701e5c-caea-4eea-8b70-8fd9dd4456ea',
#    'ticker': 'KXGRAMROTY-67-NLU',
#    'order_id': '6d0203fe-11be-4122-abe6-a85c04a92dd1',
#    'side': 'yes',
#    'action': 'buy',
#    'count': 50,
#    'yes_price': 76,
#    'no_price': 24,
#    'is_taker': False,
#    'created_time': '2024-12-13T09:55:12.948012Z'},
#   {'trade_id': '11e44c3e-f85b-489e-9bee-db5676f3e8c9',
#    'ticker': 'KXRUBIO-25JUL01-LT',
#    'order_id': '6fa22dca-c179-4361-923e-f897a1bfb3e2',
#    'side': 'yes',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 99,
#    'no_price': 1,
#    'is_taker': False,
#    'created_time': '2024-12-13T08:44:50.567336Z'},
#   {'trade_id': 'a18fc273-9c4c-4503-b565-0294428d601e',
#    'ticker': 'KXRUBIO-25JUL01-JU',
#    'order_id': '55e5b042-1d6f-4b3e-9e5f-c1c93d479d35',
#    'side': 'yes',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 99,
#    'no_price': 1,
#    'is_taker': False,
#    'created_time': '2024-12-13T08:44:38.497061Z'},
#   {'trade_id': '2f501072-214c-43ac-bf00-74b0a898f2b5',
#    'ticker': 'TOPALBUMBYZEDD-2-24',
#    'order_id': '5f1a8959-4b33-4d77-9a03-4744e0b43cff',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 1,
#    'no_price': 99,
#    'is_taker': True,
#    'created_time': '2024-12-11T15:33:30.130411Z'},
#   {'trade_id': 'f03940b5-d4a6-42bf-9d25-768c3d56b2b2',
#    'ticker': 'TOPALBUMBYZEDD-2-24',
#    'order_id': 'c7db6460-46f4-47c7-aaa3-ea14944f7813',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 1,
#    'no_price': 99,
#    'is_taker': True,
#    'created_time': '2024-12-11T01:07:27.957849Z'},
#   {'trade_id': '613d69c8-79b8-4d10-bb6c-de3f1034f630',
#    'ticker': 'KXGRAMMYWINNERS-67BNAXXROTYXXSOTY-CRXXTHEXXBOAF',
#    'order_id': 'b06bd7ce-2aa3-46ba-b2cc-6053ddf4428a',
#    'side': 'yes',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 8,
#    'no_price': 92,
#    'is_taker': True,
#    'created_time': '2024-12-10T23:03:44.17105Z'},
#   {'trade_id': '16f2d734-4898-4b6c-a88b-5dd4eab2dcfb',
#    'ticker': 'KXGRAMMYWINNERS-67BNAXXROTYXXSOTY-CRXXTHEXXBOAF',
#    'order_id': 'b06bd7ce-2aa3-46ba-b2cc-6053ddf4428a',
#    'side': 'yes',
#    'action': 'buy',
#    'count': 10,
#    'yes_price': 8,
#    'no_price': 92,
#    'is_taker': True,
#    'created_time': '2024-12-10T23:03:44.17105Z'},
#   {'trade_id': '5e170c2c-1d79-4d8c-baaa-30d5793c037e',
#    'ticker': 'KXGRAMMYWINNERS-67AOTYXXBNAXXROTYXXSOTY-NBSXXKXXTHEXXTHE',
#    'order_id': '8d609b9c-badc-4084-be86-9e6a108d9023',
#    'side': 'yes',
#    'action': 'buy',
#    'count': 10,
#    'yes_price': 6,
#    'no_price': 94,
#    'is_taker': True,
#    'created_time': '2024-12-10T14:52:20.204172Z'},
#   {'trade_id': '1a9d76c6-0eef-4278-88cc-83b8b0254e8d',
#    'ticker': 'KXGRAMMYWINNERS-67AOTYXXROTY-TTPDXXTHE',
#    'order_id': '7d0a087f-8efa-4de6-8799-5cc40d8c21fd',
#    'side': 'yes',
#    'action': 'buy',
#    'count': 10,
#    'yes_price': 5,
#    'no_price': 95,
#    'is_taker': True,
#    'created_time': '2024-12-10T04:20:39.458991Z'},
#   {'trade_id': '19786a59-5f29-4ab7-959a-5def2b3bf909',
#    'ticker': 'KXGRAMMYWINNERS-67AOTYXXROTY-TTPDXXTHE',
#    'order_id': '7d0a087f-8efa-4de6-8799-5cc40d8c21fd',
#    'side': 'yes',
#    'action': 'buy',
#    'count': 8,
#    'yes_price': 5,
#    'no_price': 95,
#    'is_taker': True,
#    'created_time': '2024-12-10T04:20:39.458991Z'},
#   {'trade_id': '2b952423-2dd0-4fc3-9061-53421d44d25f',
#    'ticker': 'KXGRAMMYWINNERS-67AOTYXXSOTY-TTPDXXBOAF',
#    'order_id': '3ab609ec-bd10-43de-aea3-879118a5073f',
#    'side': 'yes',
#    'action': 'buy',
#    'count': 5,
#    'yes_price': 17,
#    'no_price': 83,
#    'is_taker': True,
#    'created_time': '2024-12-10T04:19:23.307767Z'},
#   {'trade_id': '28ad4520-bef0-42b5-9477-1d34d27e28d5',
#    'ticker': 'KXGRAMMYWINNERS-67AOTYXXSOTY-TTPDXXBOAF',
#    'order_id': 'aee150e4-571c-459b-a9bf-910a0e46254f',
#    'side': 'yes',
#    'action': 'buy',
#    'count': 5,
#    'yes_price': 17,
#    'no_price': 83,
#    'is_taker': True,
#    'created_time': '2024-12-10T04:18:25.601452Z'},
#   {'trade_id': 'b0d87f8c-bd1d-41e7-b997-82687d3f3b42',
#    'ticker': 'KXOSCARNOMINEESPIC-25-(B)(DP2)(F)(G2)(JFAD)(KOK)(M)(M17)(SS)(WLIT)',
#    'order_id': '3df11521-b530-4625-81b6-de00340226a2',
#    'side': 'yes',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 60,
#    'no_price': 40,
#    'is_taker': True,
#    'created_time': '2024-12-07T22:05:31.019993Z'},
#   {'trade_id': '61cb8cf7-3e5e-40c2-ab02-02b6bb30a545',
#    'ticker': 'KXOSCARNOMINEESPIC-25-(B)(DP2)(F)(G2)(JFAD)(KOK)(M)(M17)(SS)(WLIT)',
#    'order_id': 'b1df7bc6-1ccc-4471-a93d-10cee0d130d0',
#    'side': 'yes',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 60,
#    'no_price': 40,
#    'is_taker': True,
#    'created_time': '2024-12-07T06:03:26.139643Z'},
#   {'trade_id': '80ef4601-8ab6-4901-92f5-225de6ecd0ec',
#    'ticker': 'TOPARTIST-24-TS',
#    'order_id': '5e94872d-856f-4264-b6bf-b056478d60e2',
#    'side': 'yes',
#    'action': 'buy',
#    'count': 5,
#    'yes_price': 91,
#    'no_price': 9,
#    'is_taker': True,
#    'created_time': '2024-12-03T20:25:40.459919Z'},
#   {'trade_id': 'd1845661-94e3-4903-8dcf-62e5a50e42d2',
#    'ticker': '1SONGCHAPPELLROAN-DEC2824',
#    'order_id': '87ac1f16-e9c2-4839-9502-baebf05b94eb',
#    'side': 'yes',
#    'action': 'buy',
#    'count': 81,
#    'yes_price': 27,
#    'no_price': 73,
#    'is_taker': True,
#    'created_time': '2024-12-02T23:34:34.440059Z'},
#   {'trade_id': '3c66c48f-d0ae-41cf-b686-37620dba3354',
#    'ticker': 'SORA-24-DEC31',
#    'order_id': '6d9930bd-b593-427c-87bd-785366979416',
#    'side': 'yes',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 41,
#    'no_price': 59,
#    'is_taker': True,
#    'created_time': '2024-11-27T07:10:03.18744Z'},
#   {'trade_id': '099b97d4-5ca6-4766-8c68-b028d5c69471',
#    'ticker': 'SORA-24-DEC31',
#    'order_id': 'db9d311c-8ce1-40b2-9997-615e0289a44a',
#    'side': 'yes',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 41,
#    'no_price': 59,
#    'is_taker': True,
#    'created_time': '2024-11-27T06:47:08.980056Z'},
#   {'trade_id': '8ea986c2-f2dd-43ec-9faa-5d93a949bf45',
#    'ticker': 'SORA-24-DEC31',
#    'order_id': 'd1bcf09e-5647-43ce-8b30-913b52cbbdc8',
#    'side': 'no',
#    'action': 'sell',
#    'count': 1,
#    'yes_price': 36,
#    'no_price': 64,
#    'is_taker': True,
#    'created_time': '2024-11-27T06:03:21.743394Z'},
#   {'trade_id': '4615edbd-107c-4e52-a5e5-5f30506d6fb5',
#    'ticker': 'SORA-24-DEC31',
#    'order_id': '2cfd7f3f-b959-458c-b1aa-cbc827c44dad',
#    'side': 'yes',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 41,
#    'no_price': 59,
#    'is_taker': True,
#    'created_time': '2024-11-27T05:55:28.128751Z'},
#   {'trade_id': 'cb2c0219-9c6b-4404-94a3-9af2ac654548',
#    'ticker': 'SORA-24-DEC31',
#    'order_id': '0be75d08-149c-4d64-baff-d81884c7b385',
#    'side': 'yes',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 41,
#    'no_price': 59,
#    'is_taker': True,
#    'created_time': '2024-11-27T05:47:12.886984Z'},
#   {'trade_id': 'b221dcf5-b460-4a00-853d-5d1760de799b',
#    'ticker': 'SORA-24-DEC31',
#    'order_id': '9f447b97-d031-43df-af74-1e266e9bd298',
#    'side': 'yes',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 41,
#    'no_price': 59,
#    'is_taker': True,
#    'created_time': '2024-11-27T05:45:27.70695Z'},
#   {'trade_id': 'e405e570-9722-4040-8d97-25698d84295b',
#    'ticker': 'SORA-24-DEC31',
#    'order_id': '51faf9a1-49cd-46f9-929a-522bee506063',
#    'side': 'yes',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 41,
#    'no_price': 59,
#    'is_taker': True,
#    'created_time': '2024-11-27T05:26:06.343135Z'},
#   {'trade_id': '57cd05ec-b484-4726-9f19-bd7a41cbbc25',
#    'ticker': 'RHGOLD-Q3-24-2.1',
#    'order_id': '76d07af1-8de8-4c68-9f31-4888eb631b0c',
#    'side': 'no',
#    'action': 'sell',
#    'count': 1,
#    'yes_price': 77,
#    'no_price': 23,
#    'is_taker': True,
#    'created_time': '2024-11-24T14:04:07.20832Z'},
#   {'trade_id': '4531b823-13ed-4aa7-abb9-80d6b81658ad',
#    'ticker': 'RHGOLD-Q3-24-2.1',
#    'order_id': '1b351be2-b445-44a9-a42a-04998d61714d',
#    'side': 'yes',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 83,
#    'no_price': 17,
#    'is_taker': True,
#    'created_time': '2024-11-24T14:03:57.059488Z'},
#   {'trade_id': '04011830-602a-4a1f-911d-00949f05a3d1',
#    'ticker': 'RHGOLD-Q3-24-2.2',
#    'order_id': '73a71601-9579-4c1a-a621-6912a555b66d',
#    'side': 'yes',
#    'action': 'buy',
#    'count': 3,
#    'yes_price': 62,
#    'no_price': 38,
#    'is_taker': True,
#    'created_time': '2024-11-23T15:35:43.601989Z'},
#   {'trade_id': '60568df5-a0a7-4356-adf3-970c7a14b8d5',
#    'ticker': 'RHGOLD-Q3-24-2.2',
#    'order_id': '44998db3-9e16-4058-85d4-7f4236806008',
#    'side': 'no',
#    'action': 'sell',
#    'count': 2,
#    'yes_price': 56,
#    'no_price': 44,
#    'is_taker': True,
#    'created_time': '2024-11-23T15:35:34.197171Z'},
#   {'trade_id': 'c2523d05-bbf6-4c9c-b92d-41e43db78a7d',
#    'ticker': 'RHGOLD-Q3-24-2.2',
#    'order_id': '3a072db7-b13e-4e89-a646-1c9bc95b18bb',
#    'side': 'yes',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 62,
#    'no_price': 38,
#    'is_taker': True,
#    'created_time': '2024-11-23T15:34:55.394075Z'},
#   {'trade_id': '912e1bbe-34ed-43bb-838b-59e858ef5c73',
#    'ticker': 'RHGOLD-Q3-24-2.2',
#    'order_id': 'b0028a9e-7d36-40fb-bf78-b50cc01a669e',
#    'side': 'yes',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 62,
#    'no_price': 38,
#    'is_taker': True,
#    'created_time': '2024-11-23T15:33:57.836749Z'},
#   {'trade_id': 'c8cf5dd5-8d14-4f5f-b22f-a8dfa884bb79',
#    'ticker': 'RHGOLD-Q3-24-2.2',
#    'order_id': '1aaeee5a-93f2-47db-82e8-b1148c031a61',
#    'side': 'no',
#    'action': 'sell',
#    'count': 1,
#    'yes_price': 56,
#    'no_price': 44,
#    'is_taker': True,
#    'created_time': '2024-11-23T15:33:50.44156Z'},
#   {'trade_id': '7931acbd-2cdb-49cd-9f4d-dc43b2ae8ad6',
#    'ticker': 'RHGOLD-Q3-24-2.2',
#    'order_id': 'b78c6164-3e00-4e52-8761-325b0b414290',
#    'side': 'yes',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 62,
#    'no_price': 38,
#    'is_taker': True,
#    'created_time': '2024-11-23T15:33:43.013484Z'},
#   {'trade_id': 'e5ee5395-d9a3-4393-b554-aaf7d1a62a2c',
#    'ticker': 'RHGOLD-Q3-24-2.2',
#    'order_id': 'df0cc42b-5d97-4f19-a5e1-710c90859cf2',
#    'side': 'no',
#    'action': 'sell',
#    'count': 1,
#    'yes_price': 56,
#    'no_price': 44,
#    'is_taker': True,
#    'created_time': '2024-11-23T15:33:38.304654Z'},
#   {'trade_id': '889769cb-0711-4425-bae5-c012376c39d6',
#    'ticker': 'RHGOLD-Q3-24-2.2',
#    'order_id': 'f378ff3c-68fd-4aee-984a-2caf5fb510cc',
#    'side': 'yes',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 62,
#    'no_price': 38,
#    'is_taker': True,
#    'created_time': '2024-11-23T15:32:35.509248Z'},
#   {'trade_id': 'cbd5174f-74f4-41e5-b5c2-37134d5fed23',
#    'ticker': 'RHGOLD-Q3-24-2.2',
#    'order_id': '87f50217-c14c-41bc-8b43-c6eb7b1d48df',
#    'side': 'no',
#    'action': 'sell',
#    'count': 1,
#    'yes_price': 56,
#    'no_price': 44,
#    'is_taker': True,
#    'created_time': '2024-11-23T15:31:55.581932Z'},
#   {'trade_id': 'd9a51f2c-78cc-4207-b10d-31d5b6143e4c',
#    'ticker': 'RHGOLD-Q3-24-2.2',
#    'order_id': 'b62e6dac-750c-4b65-bc04-7b8315b1f81b',
#    'side': 'yes',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 62,
#    'no_price': 38,
#    'is_taker': True,
#    'created_time': '2024-11-23T15:31:40.346223Z'},
#   {'trade_id': '504fb673-c0c8-483d-9758-6df96f4b071f',
#    'ticker': 'RHGOLD-Q3-24-2.2',
#    'order_id': '17716b91-6e31-461d-b415-b39fb2b0540c',
#    'side': 'no',
#    'action': 'sell',
#    'count': 1,
#    'yes_price': 56,
#    'no_price': 44,
#    'is_taker': True,
#    'created_time': '2024-11-23T15:31:31.688143Z'},
#   {'trade_id': 'c3515eb0-6bec-4337-b4f5-019eb099e1ec',
#    'ticker': 'RHGOLD-Q3-24-2.2',
#    'order_id': '2ce2e0f0-8b08-4315-9b03-46d1f5eb8715',
#    'side': 'yes',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 62,
#    'no_price': 38,
#    'is_taker': True,
#    'created_time': '2024-11-23T15:31:18.308075Z'},
#   {'trade_id': '3eb4e303-ff0b-4064-9559-429b1a8bd7cd',
#    'ticker': 'SPACEXCOUNT-24-140',
#    'order_id': 'bc40f792-19e2-4c6e-8454-22ef751e98e8',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 10,
#    'no_price': 90,
#    'is_taker': True,
#    'created_time': '2024-11-19T23:21:37.91252Z'},
#   {'trade_id': 'f5fbdc3e-a8e3-4237-a026-a42795103e89',
#    'ticker': 'SPACEXCOUNT-24-140',
#    'order_id': '959739dc-12d4-44e3-b467-74ed94afcea7',
#    'side': 'yes',
#    'action': 'buy',
#    'count': 5,
#    'yes_price': 17,
#    'no_price': 83,
#    'is_taker': True,
#    'created_time': '2024-11-19T23:21:30.923775Z'},
#   {'trade_id': '810c00da-a52c-4afb-8070-3002b96e580a',
#    'ticker': 'USTESTSREADING-24-SI2',
#    'order_id': '0562256e-31b6-4b0e-926b-3f5c8b8a03ca',
#    'side': 'yes',
#    'action': 'buy',
#    'count': 10,
#    'yes_price': 10,
#    'no_price': 90,
#    'is_taker': False,
#    'created_time': '2024-11-10T06:48:04.733644Z'},
#   {'trade_id': 'fa24fe9f-22f5-4757-8332-484fb5bfa0d5',
#    'ticker': 'USTESTSREADING-24-SD',
#    'order_id': '4a13949e-ce3a-41b4-9e44-c3bb072e6aee',
#    'side': 'yes',
#    'action': 'buy',
#    'count': 78,
#    'yes_price': 70,
#    'no_price': 30,
#    'is_taker': True,
#    'created_time': '2024-11-10T06:31:15.427901Z'},
#   {'trade_id': 'aa806ca6-b04b-4f8d-a1c1-245dd25b9452',
#    'ticker': 'XCEOCHANGE-24DEC31',
#    'order_id': '2e915bf4-9059-444a-9c93-2e9b90b80360',
#    'side': 'yes',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 31,
#    'no_price': 69,
#    'is_taker': True,
#    'created_time': '2024-11-04T05:53:45.194002Z'},
#   {'trade_id': '4a6f2ed2-c897-46c7-b8ce-8f9ecdeb801c',
#    'ticker': 'SPACEXORBIT-24-DEC31',
#    'order_id': 'd6d57493-329d-4e1d-9e67-ad58116e4a36',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 42,
#    'no_price': 58,
#    'is_taker': True,
#    'created_time': '2024-10-23T02:27:01.312186Z'},
#   {'trade_id': 'ac2adf34-9c4f-43a4-bf6b-0a936f3a928c',
#    'ticker': 'TOPALBUMCHAPPELL-24',
#    'order_id': '64a750bf-3766-4b0e-bf3f-638901346e39',
#    'side': 'no',
#    'action': 'buy',
#    'count': 60,
#    'yes_price': 34,
#    'no_price': 66,
#    'is_taker': True,
#    'created_time': '2024-10-23T02:25:59.049684Z'},
#   {'trade_id': '797d78a5-6c79-435c-afba-47397212d8dc',
#    'ticker': 'TOPALBUMCHAPPELL-24',
#    'order_id': '64a750bf-3766-4b0e-bf3f-638901346e39',
#    'side': 'no',
#    'action': 'buy',
#    'count': 40,
#    'yes_price': 36,
#    'no_price': 64,
#    'is_taker': True,
#    'created_time': '2024-10-23T02:25:59.049684Z'},
#   {'trade_id': '4d83fb75-87c6-4dd0-b01f-bba8ffe6f64c',
#    'ticker': 'STARSHIPMARS-29DEC31',
#    'order_id': 'b65c92ad-9bad-4cae-b4b6-8faf37c8bdc2',
#    'side': 'yes',
#    'action': 'buy',
#    'count': 100,
#    'yes_price': 20,
#    'no_price': 80,
#    'is_taker': True,
#    'created_time': '2024-10-23T02:25:30.745887Z'},
#   {'trade_id': 'bb426c87-4e09-47e8-991c-de1e20e39253',
#    'ticker': 'APPLEUS-29DEC31',
#    'order_id': '9c6d0554-57fc-4e13-98d1-13897ea056ff',
#    'side': 'no',
#    'action': 'buy',
#    'count': 10,
#    'yes_price': 46,
#    'no_price': 54,
#    'is_taker': True,
#    'created_time': '2024-10-23T02:25:09.089797Z'},
#   {'trade_id': '9292f724-3585-4df0-9c11-b3bed74d9eec',
#    'ticker': 'FEDHIKE-24DEC31',
#    'order_id': 'e65516a9-4649-490d-9e11-4a88940a4f09',
#    'side': 'yes',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 4,
#    'no_price': 96,
#    'is_taker': True,
#    'created_time': '2024-10-23T02:24:44.198931Z'},
#   {'trade_id': '0b3bf3b0-91ad-44e6-9f42-87af6a69daec',
#    'ticker': 'FEDHIKE-24DEC31',
#    'order_id': 'e65516a9-4649-490d-9e11-4a88940a4f09',
#    'side': 'yes',
#    'action': 'buy',
#    'count': 149,
#    'yes_price': 19,
#    'no_price': 81,
#    'is_taker': True,
#    'created_time': '2024-10-23T02:24:44.198931Z'},
#   {'trade_id': '72dea2fc-aa0c-4de2-8ca2-e6f3695a7450',
#    'ticker': 'ROBOTAXIOUT-26-JAN01',
#    'order_id': '588ccea3-209f-4ae6-a5c6-61c4d84af02e',
#    'side': 'no',
#    'action': 'buy',
#    'count': 55,
#    'yes_price': 44,
#    'no_price': 56,
#    'is_taker': True,
#    'created_time': '2024-10-23T02:21:42.750199Z'},
#   {'trade_id': '3fdb8926-d4fd-4346-b52f-b7dcd9413687',
#    'ticker': 'ROBOTAXIOUT-26-JAN01',
#    'order_id': '588ccea3-209f-4ae6-a5c6-61c4d84af02e',
#    'side': 'no',
#    'action': 'buy',
#    'count': 104,
#    'yes_price': 42,
#    'no_price': 58,
#    'is_taker': True,
#    'created_time': '2024-10-23T02:21:42.750199Z'},
#   {'trade_id': '9f19649c-a341-41ba-8ba7-fb67d99cf868',
#    'ticker': 'SHUTDOWNBY-24',
#    'order_id': '684737c5-9f6e-441b-a7c3-7ed81cf00225',
#    'side': 'no',
#    'action': 'buy',
#    'count': 500,
#    'yes_price': 11,
#    'no_price': 89,
#    'is_taker': True,
#    'created_time': '2024-10-23T02:18:55.977164Z'},
#   {'trade_id': '3e005292-60fe-49f5-b843-c0bd298039e0',
#    'ticker': 'SHUTDOWNBY-24',
#    'order_id': '684737c5-9f6e-441b-a7c3-7ed81cf00225',
#    'side': 'no',
#    'action': 'buy',
#    'count': 219,
#    'yes_price': 12,
#    'no_price': 88,
#    'is_taker': True,
#    'created_time': '2024-10-23T02:18:55.977164Z'},
#   {'trade_id': '03956bc8-e90a-4fab-8e43-08b761ba8059',
#    'ticker': 'SHUTDOWNBY-24',
#    'order_id': '684737c5-9f6e-441b-a7c3-7ed81cf00225',
#    'side': 'no',
#    'action': 'buy',
#    'count': 500,
#    'yes_price': 10,
#    'no_price': 90,
#    'is_taker': True,
#    'created_time': '2024-10-23T02:18:55.977164Z'},
#   {'trade_id': '0ae8da13-5d9d-4f83-9f63-7e5bb209b464',
#    'ticker': 'DEBATES24-3',
#    'order_id': '42c8b0e5-8c31-409f-85ad-d67c272a6267',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 68,
#    'no_price': 32,
#    'is_taker': True,
#    'created_time': '2024-10-06T00:40:08.078188Z'},
#   {'trade_id': '01351f1f-43c4-4d7c-bcda-73d3900bbdb2',
#    'ticker': 'DEBATES24-3',
#    'order_id': '42c8b0e5-8c31-409f-85ad-d67c272a6267',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 72,
#    'no_price': 28,
#    'is_taker': True,
#    'created_time': '2024-10-06T00:40:08.078188Z'},
#   {'trade_id': '04f1c0b3-2297-4213-b4f4-94df91215b49',
#    'ticker': 'WRECSS-26-PRC',
#    'order_id': '48f4f670-2d98-4382-bb85-0c52356e603f',
#    'side': 'no',
#    'action': 'buy',
#    'count': 80,
#    'yes_price': 28,
#    'no_price': 72,
#    'is_taker': False,
#    'created_time': '2024-09-23T14:05:07.38277Z'},
#   {'trade_id': '52751b6b-fd60-4317-9aba-4de435d1688d',
#    'ticker': 'WRECSS-26-IN',
#    'order_id': 'ce23e5c2-2f1e-457d-a325-6829cd65fa56',
#    'side': 'no',
#    'action': 'buy',
#    'count': 20,
#    'yes_price': 24,
#    'no_price': 76,
#    'is_taker': False,
#    'created_time': '2024-09-23T12:39:23.387263Z'},
#   {'trade_id': '4f67be84-8915-46fc-ac64-c580f3d9bf31',
#    'ticker': 'WRECSS-26-JP',
#    'order_id': '5a72f0bc-7d10-4b54-9de3-d917e0f1a8e0',
#    'side': 'no',
#    'action': 'buy',
#    'count': 50,
#    'yes_price': 72,
#    'no_price': 28,
#    'is_taker': True,
#    'created_time': '2024-09-23T11:42:12.37144Z'}],
#  'cursor': 'EhIKEE9nvoSJFUb8rGTFgPPZvzEaDAiUqMW3BhCA846xAQ'}

# %%
# you may even want to check on some of your recent positions settled...

settlement_params = {
    'limit':  None,
    'cursor': None,
}

settlements = exchange_client.get_portfolio_settlements(**settlement_params)
settlements
# Out:
# {'settlements': [{'ticker': 'KXTRUMPPARDON-25MAY01-EA',
#    'market_result': 'no',
#    'yes_count': 1,
#    'yes_total_cost': 30,
#    'no_count': 5,
#    'no_total_cost': 365,
#    'revenue': 400,
#    'settled_time': '2025-05-09T18:42:36.614628Z'},
#   {'ticker': 'KXTRUMPPARDON-25MAY01-SB',
#    'market_result': 'no',
#    'yes_count': 0,
#    'yes_total_cost': 0,
#    'no_count': 5,
#    'no_total_cost': 300,
#    'revenue': 500,
#    'settled_time': '2025-05-09T18:42:35.684066Z'},
#   {'ticker': 'DEBATES24-3',
#    'market_result': 'no',
#    'yes_count': 0,
#    'yes_total_cost': 0,
#    'no_count': 2,
#    'no_total_cost': 60,
#    'revenue': 200,
#    'settled_time': '2025-03-14T10:27:18.006217Z'},
#   {'ticker': 'KXGRAMROTY-67-NLU',
#    'market_result': 'yes',
#    'yes_count': 50,
#    'yes_total_cost': 3800,
#    'no_count': 0,
#    'no_total_cost': 0,
#    'revenue': 5000,
#    'settled_time': '2025-02-07T21:46:55.801047Z'},
#   {'ticker': 'KXGRAMROTY-67-E',
#    'market_result': 'no',
#    'yes_count': 0,
#    'yes_total_cost': 0,
#    'no_count': 0,
#    'no_total_cost': 0,
#    'revenue': 0,
#    'settled_time': '2025-02-07T21:46:55.801047Z'},
#   {'ticker': 'USTESTSREADING-24-SI2',
#    'market_result': 'no',
#    'yes_count': 10,
#    'yes_total_cost': 100,
#    'no_count': 0,
#    'no_total_cost': 0,
#    'revenue': 0,
#    'settled_time': '2025-02-07T20:30:26.801246Z'},
#   {'ticker': 'USTESTSREADING-24-SD',
#    'market_result': 'yes',
#    'yes_count': 78,
#    'yes_total_cost': 5460,
#    'no_count': 0,
#    'no_total_cost': 0,
#    'revenue': 7800,
#    'settled_time': '2025-02-07T20:30:26.801246Z'},
#   {'ticker': 'KXSECTREASURY-26DEC31-SB',
#    'market_result': 'yes',
#    'yes_count': 2,
#    'yes_total_cost': 194,
#    'no_count': 0,
#    'no_total_cost': 0,
#    'revenue': 200,
#    'settled_time': '2025-02-07T20:28:46.800928Z'},
#   {'ticker': 'KXRUBIO-25JUL01-LT',
#    'market_result': 'no',
#    'yes_count': 1,
#    'yes_total_cost': 99,
#    'no_count': 0,
#    'no_total_cost': 0,
#    'revenue': 0,
#    'settled_time': '2025-01-24T05:50:42.158299Z'},
#   {'ticker': 'KXRUBIO-25JUL01-JU',
#    'market_result': 'no',
#    'yes_count': 1,
#    'yes_total_cost': 99,
#    'no_count': 0,
#    'no_total_cost': 0,
#    'revenue': 0,
#    'settled_time': '2025-01-24T05:50:42.158299Z'},
#   {'ticker': 'ZYNBAN-24',
#    'market_result': 'no',
#    'yes_count': 7,
#    'yes_total_cost': 84,
#    'no_count': 0,
#    'no_total_cost': 0,
#    'revenue': 0,
#    'settled_time': '2025-01-01T07:37:21.710266Z'},
#   {'ticker': 'SHUTDOWNBY-24',
#    'market_result': 'no',
#    'yes_count': 0,
#    'yes_total_cost': 0,
#    'no_count': 1219,
#    'no_total_cost': 108772,
#    'revenue': 121900,
#    'settled_time': '2025-01-01T07:22:57.690948Z'},
#   {'ticker': 'SPACEXCOUNT-24-140',
#    'market_result': 'no',
#    'yes_count': 5,
#    'yes_total_cost': 85,
#    'no_count': 1,
#    'no_total_cost': 90,
#    'revenue': 0,
#    'settled_time': '2025-01-01T07:22:53.690801Z'},
#   {'ticker': 'SPACEXORBIT-24-DEC31',
#    'market_result': 'no',
#    'yes_count': 0,
#    'yes_total_cost': 0,
#    'no_count': 1,
#    'no_total_cost': 58,
#    'revenue': 100,
#    'settled_time': '2025-01-01T07:22:48.700268Z'},
#   {'ticker': 'FEDHIKE-24DEC31',
#    'market_result': 'no',
#    'yes_count': 150,
#    'yes_total_cost': 2835,
#    'no_count': 0,
#    'no_total_cost': 0,
#    'revenue': 0,
#    'settled_time': '2025-01-01T07:22:07.740575Z'},
#   {'ticker': '1SONGCHAPPELLROAN-DEC2824',
#    'market_result': 'no',
#    'yes_count': 81,
#    'yes_total_cost': 2187,
#    'no_count': 0,
#    'no_total_cost': 0,
#    'revenue': 0,
#    'settled_time': '2024-12-24T16:08:23.033218Z'},
#   {'ticker': 'TOPALBUMBYZEDD-2-24',
#    'market_result': 'no',
#    'yes_count': 0,
#    'yes_total_cost': 0,
#    'no_count': 2,
#    'no_total_cost': 198,
#    'revenue': 200,
#    'settled_time': '2024-12-23T18:09:27.895645Z'},
#   {'ticker': 'TOPALBUMCHAPPELL-24',
#    'market_result': 'no',
#    'yes_count': 0,
#    'yes_total_cost': 0,
#    'no_count': 100,
#    'no_total_cost': 6520,
#    'revenue': 10000,
#    'settled_time': '2024-12-23T18:09:25.896344Z'},
#   {'ticker': 'KXETH-24DEC1217-B3940',
#    'market_result': 'no',
#    'yes_count': 0,
#    'yes_total_cost': 0,
#    'no_count': 0,
#    'no_total_cost': 0,
#    'revenue': 0,
#    'settled_time': '2024-12-12T22:13:30.662757Z'},
#   {'ticker': 'KXETH-24DEC1217-B3900',
#    'market_result': 'no',
#    'yes_count': 0,
#    'yes_total_cost': 0,
#    'no_count': 0,
#    'no_total_cost': 0,
#    'revenue': 0,
#    'settled_time': '2024-12-12T22:13:30.662757Z'},
#   {'ticker': 'KXETH-24DEC1217-B3820',
#    'market_result': 'no',
#    'yes_count': 0,
#    'yes_total_cost': 0,
#    'no_count': 0,
#    'no_total_cost': 0,
#    'revenue': 0,
#    'settled_time': '2024-12-12T22:13:30.662757Z'},
#   {'ticker': 'NYTSUBS-24-Q3-300000',
#    'market_result': 'no',
#    'yes_count': 50,
#    'yes_total_cost': 2750,
#    'no_count': 0,
#    'no_total_cost': 0,
#    'revenue': 0,
#    'settled_time': '2024-12-11T05:43:39.552886Z'},
#   {'ticker': 'NYTSUBS-24-Q3-150000',
#    'market_result': 'yes',
#    'yes_count': 0,
#    'yes_total_cost': 0,
#    'no_count': 50,
#    'no_total_cost': 250,
#    'revenue': 0,
#    'settled_time': '2024-12-11T05:43:38.602783Z'},
#   {'ticker': 'RHGOLD-Q3-24-2.1',
#    'market_result': 'yes',
#    'yes_count': 1,
#    'yes_total_cost': 83,
#    'no_count': 1,
#    'no_total_cost': 23,
#    'revenue': 0,
#    'settled_time': '2024-12-11T05:43:30.61267Z'},
#   {'ticker': 'RHGOLD-Q3-24-2.2',
#    'market_result': 'no',
#    'yes_count': 9,
#    'yes_total_cost': 558,
#    'no_count': 6,
#    'no_total_cost': 264,
#    'revenue': 0,
#    'settled_time': '2024-12-11T05:43:30.562754Z'},
#   {'ticker': 'TOPARTIST-24-TS',
#    'market_result': 'yes',
#    'yes_count': 5,
#    'yes_total_cost': 455,
#    'no_count': 0,
#    'no_total_cost': 0,
#    'revenue': 500,
#    'settled_time': '2024-12-11T05:28:57.55264Z'}],
#  'cursor': ''}

# %%
# Now onto placing an order...
# There are many different ways to think about placing orders at Kalshi.
# The following param examples will walk through some of those

# Limit buy order for 10 units at 30c No on GDPW-22-A3

ticker = 'TESTING-5'

order_params = {
    'ticker':               ticker,
    'client_order_id':      str(uuid.uuid4()),
    'type':                 'limit',
    'action':               'buy',
    'side':                 'no',
    'count':                10,
    'yes_price':            None, # yes_price = 100 - no_price
    'no_price':             30,   # no_price =  100 - yes_price
    'expiration_ts':        None,
    'sell_position_floor':  None,
    'buy_max_cost':         None,
}

exchange_client.create_order(**order_params)

# EQUIVALENTLY, because buying No is equivalent to selling yes...

# order_params = {'ticker':ticker,
#                     'client_order_id':str(uuid.uuid4()),
#                     'type':'limit',
#                     'action':'sell',
#                     'side':'yes',
#                     'count':10,
#                     'yes_price':None, # yes_price = 100 - no_price
#                     'no_price':30, # no_price = 100 - yes_price
#                     'expiration_ts':None,
#                     'sell_position_floor':None,
#                     'buy_max_cost':None}

# exchange_client.create_order(**order_params)


# # Market sell order for 12 units Yes on GDPW-22-A3, without flipping position

# order_params = {'ticker':ticker,
#                     'client_order_id':str(uuid.uuid4()),
#                     'type':'market',
#                     'action':'sell',
#                     'side':'yes',
#                     'count':12,
#                     'yes_price':1,
#                     'no_price':None,
#                     'expiration_ts':None,
#                     'sell_position_floor':0,
#                     'buy_max_cost':None}

# exchange_client.create_order(**order_params)

# # EQUIVALENTLY, because buying No is equivalent to selling yes...

# order_params = {'ticker':ticker,
#                     'client_order_id':str(uuid.uuid4()),
#                     'type':'market',
#                     'action':'buy',
#                     'side':'no',
#                     'count':12,
#                     'yes_price':1,
#                     'no_price':None,
#                     'expiration_ts':None,
#                     'sell_position_floor':0,
#                     'buy_max_cost':None}

# exchange_client.create_order(**order_params)
# Out:
# {'ticker': 'TESTING-5', 'client_order_id': '5f82e4e5-ffa3-421a-a112-cd4b888cddb3', 'side': 'no', 'action': 'buy', 'count': 10, 'type': 'limit', 'no_price': 30}
# {'order': {'order_id': '1c995370-d0a4-445d-94a9-be603645b082',
#   'user_id': '5b044122-9dd6-4519-bc64-82f6872352d1',
#   'ticker': 'TESTING-5',
#   'status': 'resting',
#   'yes_price': 70,
#   'no_price': 30,
#   'created_time': '2025-05-23T18:48:52.257395Z',
#   'expiration_time': None,
#   'self_trade_prevention_type': '',
#   'action': 'buy',
#   'side': 'no',
#   'type': 'limit',
#   'client_order_id': '5f82e4e5-ffa3-421a-a112-cd4b888cddb3',
#   'order_group_id': ''}}
